# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata_df = pd.read_csv(mouse_metadata_path)
study_results_df = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data_df = pd.merge(mouse_metadata_df, study_results_df, how = 'outer')


# Display the data table for preview
combined_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#trying to combine the data using different command
combined_data1_df = pd.merge(mouse_metadata_df, study_results_df, how = 'outer', on='Mouse ID')
combined_data1_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
number_of_mice = combined_data_df["Mouse ID"].nunique()
number_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = combined_data_df.shape[0]
duplicate_mice
# Out:
# 1893

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mice_data = combined_data_df[combined_data_df.duplicated(["Mouse ID"])]
duplicate_mice_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_combined_data_df = combined_data_df.drop_duplicates(subset="Mouse ID", keep="last")
clean_combined_data_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9        k403     Ramicane    Male          21          16         45
# 19       s185    Capomulin  Female           3          17         45
# 29       x401    Capomulin  Female          16          15         45
# 39       m601    Capomulin    Male          22          17         45
# 49       g791     Ramicane    Male          11          16         45
# ...       ...          ...     ...         ...         ...        ...
# 1859     z314     Stelasyn  Female          21          28          5
# 1862     z435     Propriva  Female          12          26         10
# 1872     z581    Infubinol  Female          24          25         45
# 1882     z795     Naftisol  Female          13          29         45
# 1892     z969     Naftisol    Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 9              22.050126                 1
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_data_mice_number = clean_combined_data_df.shape[0]
clean_data_mice_number
# Out:
# 249

# %%
clean_data_mice_number_unique = clean_combined_data_df.nunique()
clean_data_mice_number_unique
# Out:
# Mouse ID              249
# Drug Regimen           10
# Sex                     2
# Age_months             24
# Weight (g)             16
# Timepoint              10
# Tumor Volume (mm3)    238
# Metastatic Sites        5
# dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume.
tumor_mean = clean_combined_data_df.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
tumor_median = clean_combined_data_df.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
tumor_variance = clean_combined_data_df.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
tumor_std = clean_combined_data_df.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
tumor_sem = clean_combined_data_df.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]

# Assemble the resulting series into a single summary dataframe.
tumor_stats_results = pd.DataFrame({
    "Mean Tumor Volume":tumor_mean,
    "Median Tumor Volume":tumor_median,
    "Variance Tumor Volume":tumor_variance,
    "Standard Deviation Tumor Volume":tumor_std,
    "SEM Tumor Volume":tumor_sem, #SEM is the standard error of the mean
})

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
tumor_stats_results
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Variance Tumor Volume  \
# Drug Regimen
# Capomulin             36.667568            38.125164              32.663378
# Ceftamin              57.753977            59.851956              69.982735
# Infubinol             58.178246            60.165180              74.010875
# Ketapril              62.806191            64.487812              98.921330
# Naftisol              61.205757            63.283288             106.029927
# Placebo               60.508414            62.030594              78.759797
# Propriva              56.736964            55.841410              69.349002
# Ramicane              36.191390            36.561652              32.166354
# Stelasyn              61.001707            62.192350              90.331586
# Zoniferol             59.181258            61.840058              76.862027
#
#               Standard Deviation Tumor Volume  SEM Tumor Volume
# Drug Regimen
# ...

# %%
regimen_total = clean_combined_data_df["Drug Regimen"].value_counts()
regimen_total_df = pd.DataFrame(regimen_total)
#regimen_total = pd.DataFrame(pd.value_counts(clean_combined_data_df["Drug Regimen"]))
regimen_total_df
# Out:
#            Drug Regimen
# Ramicane             25
# Capomulin            25
# Infubinol            25
# Placebo              25
# Ceftamin             25
# Zoniferol            25
# Ketapril             25
# Propriva             25
# Naftisol             25
# Stelasyn             24

# %%
# Using the aggregation method, produce the same summary statistics in a single line

regimen_total_1_df = clean_combined_data_df.agg(['sum', 'median', 'var','std', 'sem'])
regimen_total_1_df
# Out:
#                                                  Mouse ID  \
# sum     k403s185x401m601g791s508f966m546z578j913u364n3...
# median                                                NaN
# var                                                   NaN
# std                                                   NaN
# sem                                                   NaN
#
#                                              Drug Regimen  \
# sum     RamicaneCapomulinCapomulinCapomulinRamicaneRam...
# median                                                NaN
# var                                                   NaN
# std                                                   NaN
# sem                                                   NaN
#
#                                                       Sex   Age_months  \
# sum     MaleFemaleFemaleMaleMaleMaleMaleMaleMaleFemale...  3170.000000
# median                                                NaN    13.000000
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
regimen_total_df.plot(kind="bar", color="g")
plt.title("Bar Chart of Durg Regimen")
plt.ylabel("Timepoints")
plt.xlabel("Drug Regimen")
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
x_axis = clean_combined_data_df["Drug Regimen"].value_counts().index
y_axis = clean_combined_data_df["Drug Regimen"].value_counts()
plt.bar(x_axis, y_axis, color='g' )
plt.xticks(rotation=90)
plt.ylabel("Drug Regimen")
plt.xlabel("Drug Regimen")
plt.show()

# %%
# getting the stats on gender
gender = pd.value_counts(clean_combined_data_df['Sex'])
gender
# Out:
# Male      125
# Female    124
# Name: Sex, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
pie_chart = gender.plot.pie(y='Sex', title = "Pie Chart of Gender", autopct='%1.1f%%', shadow = True, figsize=(5,5))

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
pie_chart = gender.plot(kind="pie", title= "Pie Chart of Gender", autopct='%1.1f%%')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
Capomulin = clean_combined_data_df.loc[clean_combined_data_df["Drug Regimen"] == "Capomulin"]
Ramicane = clean_combined_data_df.loc[clean_combined_data_df["Drug Regimen"] == "Ramicane"]
Infubinol = clean_combined_data_df.loc[clean_combined_data_df["Drug Regimen"] == "Infubinol"]
Ceftamin = clean_combined_data_df.loc[clean_combined_data_df["Drug Regimen"] == "Ceftamin"]

x_axisCapomulin = Capomulin["Tumor Volume (mm3)"]
x_axisRamicane = Ramicane["Tumor Volume (mm3)"]
x_axisInfubinol = Infubinol["Tumor Volume (mm3)"]
x_axisCeftamin = Ceftamin["Tumor Volume (mm3)"]

# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# For the Capomulin drug,
quartiles_Capomulin = x_axisCapomulin.quantile([.25,.5,.75])
lowerq_Capomulin = quartiles_Capomulin[0.25]
upperq_Capomulin = quartiles_Capomulin[0.75]
iqr_Capomulin = upperq_Capomulin - lowerq_Capomulin
lower_limit_Capomulin = lowerq_Capomulin - (1.5 * iqr_Capomulin)
upper_limit_Capomulin = upperq_Capomulin + (1.5 * iqr_Capomulin)
print("Drug: Capomulin")
print(quartiles_Capomulin)
print(lowerq_Capomulin)
print(upperq_Capomulin)
print(iqr_Capomulin)
print(f"Values found below {lower_limit_Capomulin} are outliers.")
print(f"Values found above {upper_limit_Capomulin} are outliers.")
    
# Locate the rows which contain mice on each drug and get the tumor volumes    
# add subset    
# Determine outliers using upper and lower bounds
# Out:
# Drug: Capomulin
# 0.25    32.377357
# 0.50    38.125164
# 0.75    40.159220
# Name: Tumor Volume (mm3), dtype: float64
# 32.37735684
# 40.1592203
# 7.781863460000004
# Values found below 20.70456164999999 are outliers.
# Values found above 51.83201549 are outliers.

# %%
#Calculate the IQR and quantitatively determine if there are any potential outliers. 
# For the Ramicane drug,
quartiles_Ramicane = x_axisRamicane.quantile([.25,.5,.75])
lowerq_Ramicane = quartiles_Ramicane[0.25]
upperq_Ramicane = quartiles_Ramicane[0.75]
iqr_Ramicane = upperq_Ramicane - lowerq_Ramicane
lower_limit_Ramicane = lowerq_Ramicane - (1.5 * iqr_Ramicane)
upper_limit_Ramicane = upperq_Ramicane + (1.5 * iqr_Ramicane)
print("Drug: Ramicane")
print(quartiles_Ramicane)
print(lowerq_Ramicane)
print(upperq_Ramicane)
print(iqr_Ramicane)
print(f"Values found below {lower_limit_Ramicane} are outliers.")
print(f"Values found above {upper_limit_Ramicane} are outliers.")
# Out:
# Drug: Ramicane
# 0.25    31.560470
# 0.50    36.561652
# 0.75    40.659006
# Name: Tumor Volume (mm3), dtype: float64
# 31.56046955
# 40.65900627
# 9.098536719999998
# Values found below 17.912664470000003 are outliers.
# Values found above 54.30681135 are outliers.

# %%
#Calculate the IQR and quantitatively determine if there are any potential outliers. 
# For the Infubinol drug,
quartiles_Infubinol = x_axisInfubinol.quantile([.25,.5,.75])
lowerq_Infubinol = quartiles_Infubinol[0.25]
upperq_Infubinol = quartiles_Infubinol[0.75]
iqr_Infubinol = upperq_Infubinol - lowerq_Infubinol
lower_limit_Infubinol = lowerq_Infubinol - (1.5 * iqr_Infubinol)
upper_limit_Infubinol = upperq_Infubinol + (1.5 * iqr_Infubinol)
print("Drug: Infubinol")
print(quartiles_Infubinol)
print(lowerq_Infubinol)
print(upperq_Infubinol)
print(iqr_Infubinol)
print(f"Values found below {lower_limit_Infubinol} are outliers.")
print(f"Values found above {upper_limit_Infubinol} are outliers.")
# Out:
# Drug: Infubinol
# 0.25    54.048608
# 0.50    60.165180
# 0.75    65.525743
# Name: Tumor Volume (mm3), dtype: float64
# 54.04860769
# 65.52574285
# 11.477135160000003
# Values found below 36.83290494999999 are outliers.
# Values found above 82.74144559000001 are outliers.

# %%
#Calculate the IQR and quantitatively determine if there are any potential outliers. 
# For the Ceftamin drug,
quartiles_Ceftamin = x_axisCeftamin.quantile([.25,.5,.75])
lowerq_Ceftamin = quartiles_Ceftamin[0.25]
upperq_Ceftamin = quartiles_Ceftamin[0.75]
iqr_Ceftamin = upperq_Infubinol - lowerq_Ceftamin
lower_limit_Ceftamin = lowerq_Infubinol - (1.5 * iqr_Ceftamin)
upper_limit_Ceftamin = upperq_Ceftamin + (1.5 * iqr_Ceftamin)
print("Drug: Ceftamin")
print(quartiles_Ceftamin)
print(lowerq_Ceftamin)
print(upperq_Ceftamin)
print(iqr_Ceftamin)
print(f"Values found below {lower_limit_Ceftamin} are outliers.")
print(f"Values found above {upper_limit_Ceftamin} are outliers.")
# Out:
# Drug: Ceftamin
# 0.25    48.722078
# 0.50    59.851956
# 0.75    64.299830
# Name: Tumor Volume (mm3), dtype: float64
# 48.72207785
# 64.29983003
# 16.803665000000002
# Values found below 28.843110189999994 are outliers.
# Values found above 89.50532753 are outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

fig1, ax1 = plt.subplots()
ax1.set_title("Regimen Study")
ax1.set_ylabel("Tumor Volume (mm3)")
ax1.boxplot([x_axisCapomulin, x_axisRamicane, x_axisInfubinol, x_axisCeftamin])
ax1.set_xticklabels(["Capomulin", "Ramicane", "Infubinol", "Ceftamin"])
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# Using Mouse ID x401 for this graph
x_axis = combined_data_df.loc[combined_data_df["Mouse ID"] == "x401"]
x_axis = x_axis["Timepoint"]
y_axis = combined_data_df.loc[combined_data_df["Mouse ID"] == "x401"]
y_axis = y_axis["Tumor Volume (mm3)"]

plt.plot(x_axis, y_axis, color='g')
plt.title("Trend of Tumor Volume to Time Point")
plt.xticks(rotation=0)
plt.xlabel("Time Point")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
mouse_weight_to_Volume = clean_combined_data_df.loc[clean_combined_data_df["Drug Regimen"] == "Capomulin"]
mouse_weight_to_Volume
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 19       s185    Capomulin  Female           3          17         45
# 29       x401    Capomulin  Female          16          15         45
# 39       m601    Capomulin    Male          22          17         45
# 64       f966    Capomulin    Male          16          17         20
# 104      u364    Capomulin    Male          18          17         45
# 124      y793    Capomulin    Male          17          17         45
# 134      r554    Capomulin  Female           8          17         45
# 144      m957    Capomulin  Female           3          19         45
# 164      t565    Capomulin  Female          20          17         45
# 204      i738    Capomulin  Female          23          20         45
# 224      w914    Capomulin    Male          24          21         45
# 244      g288    Capomulin    Male           3          19         45
# ...

# %%
#Generating the scatter plot
plt.scatter(mouse_weight_to_Volume .iloc[:,4],mouse_weight_to_Volume .iloc[:,6])
plt.title("Scatter Plot of Mouse Weight to Tumor Volume")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
#Generating the scatter plot - just trying it again differently
mouse_weight = mouse_weight_to_Volume["Weight (g)"]
tumor_volume = mouse_weight_to_Volume["Tumor Volume (mm3)"]
plt.scatter(mouse_weight, tumor_volume)
plt.title("Scatter Plot of Mouse Weight to Tumor Volume")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
mouse_weight = mouse_weight_to_Volume .iloc[:,4]
tumor_volume = mouse_weight_to_Volume .iloc[:,6]
correlation = st.pearsonr(mouse_weight, tumor_volume)
print(f"The correlation coefficient between both factors, mouse weight and tumor volume, is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between both factors, mouse weight and tumor volume, is 0.88

# %%
#ploting the linear regression model
x_values = mouse_weight
y_values = tumor_volume
(slope, intercept, rvalue, pvalue, stderror) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_equation = "y =" + str(round(slope, 2))+ "x +" + str(round(intercept, 2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r")
plt.annotate(line_equation, (16,45), fontsize=15, color="red")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Linear Regression of Mouse Weight to Tumor Volume")
print(f"The r-squared is {rvalue**2}")
plt.show()
# Out:
# The r-squared is 0.7686134812138998
